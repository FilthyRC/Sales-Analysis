# %%
#Importing libraries

import pandas as pd
import  matplotlib as plt
import os

# %%
#All yearly data combined

dir = "Sales Data/"
files = []

for file in os.listdir(dir):
    df = pd.read_csv(dir + file)
    files.append(df)


year_data = pd.concat(files)
    
year_data.dropna(inplace= True)
year_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
#Add Month column to filter data by months
year_data["Order Date"] = pd.to_datetime(year_data["Order Date"], errors="coerce")
year_data["Month"] = year_data["Order Date"].dt.month
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 1563   297150  Lightning Charging Cable                1      14.95
# 2265   297817                    iPhone                1        700
# 2266   297817  Lightning Charging Cable                2      14.95
# 2425   297969              Google Phone                1        600
# 2806   298344          Wired Headphones                4      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#               Order Date                      Purchase Address  Month
# 1563 2020-01-01 00:38:00       427 Wilson St, Dallas, TX 75001    1.0
# ...
